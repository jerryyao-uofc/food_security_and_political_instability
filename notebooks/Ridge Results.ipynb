# %% [markdown]
# # Load the Data

# %%
# basic package
import csv
import glob
import pandas as pd
import matplotlib as plt
from tqdm import tqdm
import numpy as np
import random
from operator import itemgetter
import matplotlib.pyplot as plt
import warnings


# ml related 
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import Ridge

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
political = pd.read_csv("drive/Shareddrives/ML_&_Econometrics/Merged/political_selected.csv")
undernourish = pd.read_csv("drive/Shareddrives/ML_&_Econometrics/Merged/undernourish_selected.csv")

meaning_map = pd.read_csv("drive/Shareddrives/ML_&_Econometrics/Merged/final_new_meaning_A.csv")

# %% [markdown]
# # Preparatory Code

# %%
def map_code_to_meaning(mapping, code_no):
    return (mapping.loc[mapping['code']==code_no]).iloc[0].var_name

# print the total percetnage of missing in each dataset
def total_percentage_missing(df):
    return(np.count_nonzero(df.isna()) / df.size)

# drop the top N rows with most NAs
def drop_top_N_rows_with_most_NAs(df, N=300):
    if N/len(df)> 0.2:
      warnings.warn("Based on your speficied N, you are dropping more then 20% of the data")

    print("shape before drop", df.shape)
    dict_nas = {}
    for i in range(len(df)):
        percentage = total_percentage_missing(df.iloc[i])
        dict_nas[i] = percentage
    res = dict(sorted(dict_nas.items(), key = itemgetter(1), reverse = True)[:N])
    # print("here")
    top_NAs_rows = list(res.keys())
    # print(top_NAs_rows)
    df.drop(top_NAs_rows, axis=0, inplace=True)
    print("shape after drop ", df.shape)
    print("Missing data percentage ", total_percentage_missing(df) )
    return df

# split into two dataset by year (default=2017)
# fist one include that year, second one is year after that
def split_by_year(df, split_at = 2017):
    res1 = df.loc[df['Year']<= split_at]
    res2 = df.loc[df['Year']> split_at]
    return res1, res2

def print_all_coeff(list_coef, feature_name):
    sort_index = reversed(np.argsort(list_coef))
    list_of_lists = []

    # print(sort_index)
    for d in sort_index:
      for i in d:
          # print("[i]", feature_name[i])
          # print(i)
          # print(i)
          temp = int(feature_name[i])
          list_coef 
          # print("here", len(list_coef[0]))
          if list_coef[0][i] !=0.0:
              list_of_lists.append([round(list_coef[0][i],10), feature_name[i], map_code_to_meaning(meaning_map, temp)])
    return pd.DataFrame(list_of_lists, columns =['non_zero_coefficient', 'code', 'variable_name'])

# %% [markdown]
# # Ridge Pipeline Code

# %%
  # pipeline on returning the coefficient of lasso regression
# also returns the score of the regressions
def ridge_pipeline(df, target_name = 'political', split_year = 2017, ridge_alpha = 1.0):

    if target_name not in df.columns:
        raise ValueError("The input dataframe doesn't have the column: political")
    
    if 'Continent' in df.columns:
      df = df.drop(columns =['Continent'])

    # default split at 2017
    political_pre_2017, political_post_2017 = split_by_year(df, split_at = split_year)
    
    # Note, the variable names here is only names, y_politcal can be any dataframe
    # doesn't have to be political 
    y_political = political_pre_2017.pop(target_name)
    X_political = political_pre_2017.drop(columns = ['Year', 'Area Code'])

    y_political_test = political_post_2017.pop(target_name)
    X_political_test = political_post_2017.drop(columns = ['Year', 'Area Code'])

    
    feature_names = X_political_test.columns

    # scale the X
    scaler = StandardScaler()
    political_scaler_X = scaler.fit(X_political)
    X_political_scaled = political_scaler_X.transform(X_political)
    X_political_test_scaled = political_scaler_X.transform(X_political_test)

    # scale the y
    y_political = y_political.values.reshape(-1,1)
    y_political_test = y_political_test.values.reshape(-1,1)
    political_scaler_y = scaler.fit(y_political)
    y_political_scaled = political_scaler_y.transform(y_political)
    y_political_test_scaled = political_scaler_y.transform(y_political_test)
    
    # print shapes
    print("Training Shape:", X_political_scaled.shape)
    print("Testing Shape", X_political_test_scaled.shape)
    
    # Run LASSO
    reg = Ridge(alpha=ridge_alpha).fit(X_political_scaled, y_political_scaled)

    # evaluation
    print("score on training dataset", reg.score(X_political_scaled, y_political_scaled) )
    print("score on testing dataset", reg.score(X_political_test_scaled, y_political_test_scaled))
    y_train_pred = reg.predict(X_political_scaled) # predicting for training
    y_pred = reg.predict(X_political_test_scaled)  # predicting for testing
    print("R squared score on training", r2_score(y_political_scaled, y_train_pred))
    print("R squared score on testing", r2_score(y_political_test_scaled, y_pred))
    
    print("Mean Absolute Error on training", mean_absolute_error(y_political_scaled, y_train_pred))
    print("Mean Absolute Error on testing", mean_absolute_error(y_political_test_scaled, y_pred))
    res_df = print_all_coeff(reg.coef_, feature_names)
    return res_df

# %% [markdown]
# # Process Data Before Feeding in Pipeline: check missing data and fill in NAs

# %%
# this chunck can only be run once
political = drop_top_N_rows_with_most_NAs(df= political, N= 300)
undernourish = drop_top_N_rows_with_most_NAs(df= undernourish, N= 300)
# drinking = drop_top_N_rows_with_most_NAs(df= drinking, N= 500)



# fill NAs
political = political.fillna(0)
undernourish = undernourish.fillna(0)
# drinking = drinking.fillna(0)
# Out:
# shape before drop (3705, 1002)
# shape after drop  (3405, 1002)
# Missing data percentage  0.003907896395168547
# shape before drop (3933, 1002)
# shape after drop  (3633, 1002)
# Missing data percentage  0.02336230374373741

# %% [markdown]
# # Ridge on Entire Political Dataset

# %%
ridge_pipeline(political, target_name = 'political', ridge_alpha=5e7)
# Out:
# Training Shape: (3041, 999)
# Testing Shape (364, 999)
# score on training dataset 0.0023974621123628026
# score on testing dataset -6.742856438677597
# R squared score on training 0.0023974621123628026
# R squared score on testing -6.742856438677597
# Mean Absolute Error on training 0.8170191163924648
# Mean Absolute Error on testing 0.9187033070150712
#      non_zero_coefficient        code  \
# 0               -0.000032   220166187
# 1               -0.000032   220166186
# 2               -0.000031   220166103
# 3               -0.000031   220166157
# 4               -0.000024  2203061393
# ..                    ...         ...
# 969              0.000022   220306192
# 970              0.000024   220306135
# 971              0.000032   220086119
# 972              0.000032   220116119
# 973              0.000033   220086185
#
#                                          variable_name
# 0    Value Added (Agriculture, Forestry and Fishing...
# 1    Value Added (Agriculture, Forestry and Fishing...
# 2    Value Added (Agriculture, Forestry and Fishing...
# 3    Value Added (Agriculture, Forestry and Fishing...
# 4    Gross Fixed Capital Formation (Agriculture, Fo...
# ..                                                 ...
# 969  Gross Fixed Capital Formation (Agriculture, Fo...
# 970  Gross Fixed Capital Formation (Agriculture, Fo...
# 971        Gross Domestic Product Value US$ per capita
# 972         Gross National Income Value US$ per capita
# 973  Gross Domestic Product Value US$ per capita, 2...
#
# [974 rows x 3 columns]

# %%
ridge_pipeline(undernourish, target_name = 'undernourish',  ridge_alpha=1e4)
# Out:
# Training Shape: (3055, 999)
# Testing Shape (578, 999)
# score on training dataset 0.5237278828367522
# score on testing dataset 0.28826008090278166
# R squared score on training 0.5237278828367522
# R squared score on testing 0.28826008090278166
# Mean Absolute Error on training 0.47777568565179196
# Mean Absolute Error on testing 0.48803293758325406
#      non_zero_coefficient        code  \
# 0               -0.038479    17355419
# 1               -0.034616     8825420
# 2               -0.033970    17205419
# 3               -0.029152    17835410
# 4               -0.028695    10625410
# ..                    ...         ...
# 985              0.024281     1882494
# 986              0.024774     1848494
# 987              0.027687   220306139
# 988              0.027725  2203061391
# 989              0.028051  2203061392
#
#                                          variable_name
# 0                             Vegetables Primary Yield
# 1                          Milk, whole fresh cow Yield
# 2                        Roots and Tubers, Total Yield
# 3                                   Eggs Primary Yield
# 4                            Eggs, hen, in shell Yield
# ..                                                 ...
# 985  Agricultural Products Export Unit/Value Index ...
# 986  Other food Export Unit/Value Index (2014-2016 ...
# 987  Gross Fixed Capital Formation (Agriculture, Fo...
# 988  Gross Fixed Capital Formation (Agriculture, Fo...
# 989  Gross Fixed Capital Formation (Agriculture, Fo...
#
# [990 rows x 3 columns]

# %% [markdown]
# # By Political Continent

# %% [markdown]
# ## Asia

# %%
political_Asia = pd.read_csv("drive/Shareddrives/ML_&_Econometrics/Merged/Political_continent/political_Asia.csv")

# %%
political_Asia.shape

# %%
# do not drop top NAs because the dataset already small 
print(total_percentage_missing(political_Asia))

# fill NAs
political_Asia = political_Asia.fillna(0)
# Out:
# 0.018762933168458014

# %%
lasso_pipeline(political_Asia, target_name = 'political')
# Out:
# Training Shape: (782, 999)
# Testing Shape (138, 999)
# score on training dataset 0.5954796547266706
# score on testing dataset 0.6085946584993815
# R squared score on training 0.5954796547266706
# R squared score on testing 0.6085946584993815
# Mean Absolute Error on training 0.5247211845823034
# Mean Absolute Error on testing 0.5230428070350854
#     non_zero_coefficient        code  \
# 0               0.183134    68217266
# 1               0.065124   220086185
# 2               0.055278    17527213
# 3               0.054970   220156157
# 4               0.036349    68197266
# 5               0.022375    68257264
# 6               0.022199    16335616
# 7               0.017084  6825726313
# 8               0.016251    66467209
# 9               0.006993    16335622
# 10              0.004633    66507208
# 11              0.003286     6345622
# 12              0.001000   220156103
# 13              0.000000    68257265
# 14              0.000000    68257266
# 15             -0.000000  2203061392
# 16             -0.014447    66107209
# 17             -0.021161    18065510
# 18             -0.036152    17467211
# 19             -0.037931    10585321
# 20             -0.077516  2203061394
# 21             -0.099888    66207209
# 22             -0.161884        1664
# 23             -0.180192  6818726313
#
#                                         variable_name
# 0                        Energy Emissions Share (N2O)
# 1   Gross Domestic Product Value US$ per capita, 2...
# 2   Major livestock types Livestock units per agri...
# 3   Gross Fixed Capital Formation Share of GDP Loc...
# 4                         Other Emissions Share (N2O)
# 5       All sectors with LULUCF Emissions Share (CO2)
# 6        Sawnwood, non-coniferous all Import Quantity
# 7   All sectors with LULUCF Emissions Share (CO2eq...
# 8                      Forest land Share in Land area
# 9           Sawnwood, non-coniferous all Import Value
# 10  Land under permanent crops Share in Agricultur...
# 11        Beverages, distilled alcoholic Import Value
# 12     Gross Fixed Capital Formation Share of GDP US$
# 13      All sectors with LULUCF Emissions Share (CH4)
# 14      All sectors with LULUCF Emissions Share (N2O)
# 15  Gross Fixed Capital Formation (Agriculture, Fo...
# 16               Agricultural land Share in Land area
# 17                   Beef and Buffalo Meat Production
# 18      Cattle and Buffaloes Share in total livestock
# 19        Meat, chicken Producing Animals/Slaughtered
# 20  Gross Fixed Capital Formation (Agriculture, Fo...
# 21                        Cropland Share in Land area
# 22     Flour, wheat Import Value Base Period Quantity
# 23                Waste Emissions Share (CO2eq) (AR5)

# %% [markdown]
# ## Africa

# %%
political_Africa= pd.read_csv("drive/Shareddrives/ML_&_Econometrics/Merged/Political_continent/political_Africa.csv")

# %%
political_Africa.shape
# Out:
# (1016, 1003)

# %%
# do not drop top NAs because the dataset already small 
print(total_percentage_missing(political_Africa))

# fill NAs
political_Africa = political_Africa.fillna(0)
# Out:
# 0.01907957230670194

# %%
lasso_pipeline(political_Africa, target_name = 'political')
# Out:
# Training Shape: (908, 999)
# Testing Shape (162, 999)
# score on training dataset 0.5158326942687419
# score on testing dataset 0.4858478192028174
# R squared score on training 0.5158326942687419
# R squared score on testing 0.4858478192028174
# Mean Absolute Error on training 0.5674172366603345
# Mean Absolute Error on testing 0.5066178683817737
#     non_zero_coefficient        code  \
# 0               0.109660   220116119
# 1               0.094332   220156157
# 2               0.088830    68257264
# 3               0.053910    65157266
# 4               0.046365    67937245
# 5               0.014838    10577213
# 6               0.010531   220086185
# 7               0.008764     1847464
# 8               0.005504    69917266
# 9               0.001988  6825726313
# 10              0.001327     2044434
# 11              0.000053   220156103
# 12              0.000000    68257265
# 13              0.000000    17527211
# 14              0.000000    68257266
# 15             -0.000000   220166187
# 16             -0.003185      194165
# 17             -0.014970       16464
# 18             -0.015123    69957225
# 19             -0.017303      189064
# 20             -0.042074  6518723113
# 21             -0.047592  6995724413
# 22             -0.049833    69725008
# 23             -0.061869    65187225
# 24             -0.088891    22222222
# 25             -0.099445   220316183
# 26             -0.119474   220166186
# 27             -0.131998    66705110
#
#                                         variable_name
# 0          Gross National Income Value US$ per capita
# 1   Gross Fixed Capital Formation Share of GDP Loc...
# 2       All sectors with LULUCF Emissions Share (CO2)
# 3           Food Waste Disposal Emissions Share (N2O)
# 4   Closed and open shrubland Biomass burned (dry ...
# 5   Chickens Livestock units per agricultural land...
# 6   Gross Domestic Product Value US$ per capita, 2...
# 7   Non-food Import Unit/Value Index (2014-2016 = ...
# 8          Waste - food systems Emissions Share (N2O)
# 9   All sectors with LULUCF Emissions Share (CO2eq...
# 10  Livestock Gross per capita Production Index Nu...
# 11     Gross Fixed Capital Formation Share of GDP US$
# 12      All sectors with LULUCF Emissions Share (CH4)
# 13     Major livestock types Share in total livestock
# 14      All sectors with LULUCF Emissions Share (N2O)
# 15  Value Added (Agriculture, Forestry and Fishing...
# 16  Cereal preparations Import Value Base Period P...
# 17  Flour, wheat Import Unit/Value Index (2014-201...
# 18     Emissions on agricultural land Emissions (CH4)
# 19  Sugar and Honey Import Value Base Period Quantity
# 20               Food systems Emissions (CO2eq) (AR5)
# 21  Emissions on agricultural land Emissions (CO2e...
# 22                       Woody crops Area from CCI_LC
# 23                       Food systems Emissions (CH4)
# 24              Standard local currency units per USD
# 25  Consumption of Fixed Capital (Agriculture, For...
# 26  Value Added (Agriculture, Forestry and Fishing...
# 27                                    Other land Area

# %% [markdown]
# ## Europe

# %%
political_Europe= pd.read_csv("drive/Shareddrives/ML_&_Econometrics/Merged/Political_continent/political_Europe.csv")

# %%
political_Europe.head(3)
# Out:
#    Year  Area Code Continent  political   67907246  69937225  69705008  \
# 0  2000          1    Europe      -0.68   162.5807       0.0   32.8890
# 1  2000          3    Europe      -0.54  4658.3563       0.0   15.4679
# 2  2000          6    Europe       1.17     0.0000       0.0    0.2325
#
#     67897246    67897245  67897230  ...  4725610  66555110  4635312  18675616  \
# 0   141.3584    466.4827    0.0001  ...    516.0     835.0   4900.0       0.0
# 1  3824.9803  12622.4349    0.0027  ...   6333.0     445.0    617.0       0.0
# 2     0.0000      0.0000    0.0000  ...      NaN      22.0      NaN      80.0
#
#     89864   89865  898464  898465  18675622  1719465
# 0  6920.0  3952.0    93.0    54.0       0.0      8.0
# 1   482.0  1635.0    57.0   187.0      52.0    120.0
# 2     NaN     NaN     NaN     NaN      23.0      NaN
#
# [3 rows x 1003 columns]

# %%
political_Europe.shape
# Out:
# (804, 1003)

# %%
# do not drop top NAs because the dataset already small 
print(total_percentage_missing(political_Europe))

# fill NAs
political_Europe = political_Europe.fillna(0)
# Out:
# 0.033582089552238806

# %%
lasso_pipeline(political_Europe, target_name = 'political')
# Out:
# Training Shape: (718, 999)
# Testing Shape (129, 999)
# score on training dataset 0.6912999215572092
# score on testing dataset 0.6927947324220374
# R squared score on training 0.6912999215572092
# R squared score on testing 0.6927947324220374
# Mean Absolute Error on training 0.41655314486461364
# Mean Absolute Error on testing 0.4138874600747007
#     non_zero_coefficient        code  \
# 0           2.951035e-01   220086185
# 1           1.344020e-01    69795007
# 2           2.738184e-02    10625410
# 3           1.073543e-02   220156186
# 4           0.000000e+00   220156187
# 5          -0.000000e+00   220166187
# 6          -0.000000e+00   220166157
# 7          -6.580000e-08  6987723114
# 8          -5.400878e-04    65057264
# 9          -9.252312e-03       22465
# 10         -1.835852e-02    67947230
# 11         -2.352531e-02    17355312
# 12         -2.670669e-02    65187266
# 13         -2.961105e-02     2076462
# 14         -4.409222e-02   202972380
# 15         -8.274084e-02    69877225
# 16         -1.232626e-01  1053723601
# 17         -1.365886e-01   220166186
# 18         -1.582188e-01   220166103
#
#                                         variable_name
# 0   Gross Domestic Product Value US$ per capita, 2...
# 1             Terrestrial barren land Area from MODIS
# 2                           Eggs, hen, in shell Yield
# 3   Gross Fixed Capital Formation Share of GDP Loc...
# 4   Gross Fixed Capital Formation Share of GDP US$...
# 5   Value Added (Agriculture, Forestry and Fishing...
# 6   Value Added (Agriculture, Forestry and Fishing...
# 7            Solid food waste Emissions (CO2eq) (AR4)
# 8    Food Household Consumption Emissions Share (CO2)
# 9      Pastry Import Quantity Index (2014-2016 = 100)
# 10                          Grassland Emissions (N2O)
# 11                  Vegetables Primary Area harvested
# 12                 Food systems Emissions Share (N2O)
# 13    Other Meat Import Value Index (2014-2016 = 100)
# 14   Poultry Birds Manure left on pasture (N content)
# 15                     Solid food waste CH4 emissions
# 16  Chickens, broilers Indirect emissions (N2O tha...
# 17  Value Added (Agriculture, Forestry and Fishing...
# 18  Value Added (Agriculture, Forestry and Fishing...

# %% [markdown]
# ##North America

# %%
political_NorthAmerica= pd.read_csv("drive/Shareddrives/ML_&_Econometrics/Merged/Political_continent/political_NorthAmerica.csv")

# %%
political_NorthAmerica.head(3)
# Out:
#    Year  Area Code      Continent  political    67907246  69937225  69705008  \
# 0  2000          8  North America       0.71      0.0000       0.0    0.6975
# 1  2000         12  North America       1.28  11441.5951       0.0    7.8066
# 2  2000         14  North America       1.15      0.0000       0.0    3.5051
#
#     67897246    67897245  67897230  ...  4725610  66555110  4635312  18675616  \
# 0     0.0000      0.0000    0.0000  ...     90.0       4.0     40.0      69.0
# 1  8938.5508  50838.3192    0.0107  ...   1932.0       2.0   2000.0     900.0
# 2     0.0000      0.0000    0.0000  ...   1060.0       2.0    310.0    1600.0
#
#     89864   89865  898464  898465  18675622  1719465
# 0   107.0    80.0    22.0    17.0       6.0     63.0
# 1   150.0   601.0    81.0   284.0     254.0    414.0
# 2  1859.0  3792.0    50.0   105.0     612.0    103.0
#
# [3 rows x 1003 columns]

# %%
# do not drop top NAs because the dataset already small 
print(total_percentage_missing(political_NorthAmerica))

# fill NAs
political_NorthAmerica = political_NorthAmerica.fillna(0)
# Out:
# 0.028166056155259276

# %%
lasso_pipeline(political_NorthAmerica, target_name = 'political')
# Out:
# Training Shape: (403, 999)
# Testing Shape (72, 999)
# score on training dataset 0.7273696899428135
# score on testing dataset 0.7687525012674276
# R squared score on training 0.7273696899428135
# R squared score on testing 0.7687525012674276
# Mean Absolute Error on training 0.42650202280633304
# Mean Absolute Error on testing 0.3928829493208393
#     non_zero_coefficient        code  \
# 0               0.071810   220086185
# 1               0.062255    69805008
# 2               0.051066    65057265
# 3               0.034537  6505726313
# 4               0.026232   220316183
# 5               0.004240    18725922
# 6               0.003530    18675616
# 7              -0.000000   220166157
# 8              -0.000000    65157264
# 9              -0.000000   220756103
# 10             -0.017554   220116155
# 11             -0.049730    66557209
# 12             -0.113234    69917264
# 13             -0.249918    12425610
# 14             -0.257887   220756157
# 15             -0.259490   220166103
#
#                                         variable_name
# 0   Gross Domestic Product Value US$ per capita, 2...
# 1        Permanent snow and glaciers Area from CCI_LC
# 2    Food Household Consumption Emissions Share (CH4)
# 3   Food Household Consumption Emissions Share (CO...
# 4   Consumption of Fixed Capital (Agriculture, For...
# 5                               Sawnwood Export Value
# 6   Industrial roundwood, non-coniferous Import Qu...
# 7   Value Added (Agriculture, Forestry and Fishing...
# 8           Food Waste Disposal Emissions Share (CO2)
# 9   Value Added (Total Manufacturing) Share of GDP...
# 10  Gross National Income Annual growth Local Curr...
# 11  Land under perm. meadows and pastures Share in...
# 12         Waste - food systems Emissions Share (CO2)
# 13                   Margarine, short Import Quantity
# 14  Value Added (Total Manufacturing) Share of GDP...
# 15  Value Added (Agriculture, Forestry and Fishing...

# %% [markdown]
# ## South America

# %%
political_SouthAmerica= pd.read_csv("drive/Shareddrives/ML_&_Econometrics/Merged/Political_continent/political_SouthAmerica.csv")

# %%
political_SouthAmerica.head(3)
# Out:
#    Year  Area Code      Continent  political      67907246  69937225  \
# 0  2000          9  South America       0.10  4.217921e+05       0.0
# 1  2000         19  South America      -0.24  1.104915e+06       0.0
# 2  2000         21  South America       0.19  4.404393e+06       0.0
#
#     69705008     67897246     67897245  67897230  ...  4725610  66555110  \
# 0   356.5994  295232.0537  1631116.188    0.3425  ...  11451.0   99870.0
# 1    61.6915  317945.1242  1907280.682    0.4005  ...    171.0   33831.0
# 2  1240.0209  933359.9312  5557032.985    1.1670  ...   6407.0  173453.5
#
#     4635312  18675616     89864     89865  898464  898465  18675622  1719465
# 0   53258.0    4000.0     272.0     944.0    45.0   155.0     800.0    110.0
# 1    4888.0    1200.0    3676.0   17791.0    59.0   300.0      33.0      4.0
# 2  193000.0   17240.0  194912.0  412029.0    58.0   135.0    1237.0     34.0
#
# [3 rows x 1003 columns]

# %%
# do not drop top NAs because the dataset already small 
print(total_percentage_missing(political_SouthAmerica))

# fill NAs
political_SouthAmerica = political_SouthAmerica.fillna(0)
# Out:
# 0.03315963042047945

# %%
lasso_pipeline(political_SouthAmerica, target_name = 'political')
# Out:
# Training Shape: (221, 999)
# Testing Shape (39, 999)
# score on training dataset 0.7515067863270835
# score on testing dataset 0.6058596846412243
# R squared score on training 0.7515067863270835
# R squared score on testing 0.6058596846412243
# Mean Absolute Error on training 0.38465874631348485
# Mean Absolute Error on testing 0.4278209264126954
#     non_zero_coefficient        code  \
# 0               0.156366   220306135
# 1               0.098586     1094432
# 2               0.078120    17385419
# 3               0.072218     6675610
# 4               0.066621     4725610
# 5               0.043961   220306192
# 6               0.039290     1739432
# 7               0.017148  1711726313
# 8               0.000247     2044432
# 9               0.000000   220306195
# 10             -0.002778      565610
# 11             -0.003203    19545610
# 12             -0.004662      184864
# 13             -0.009949       89864
# 14             -0.034815      184764
# 15             -0.150150        3164
# 16             -0.157095    65167264
# 17             -0.168214    68217265
# 18             -0.212107   220166183
#
#                                         variable_name
# 0   Gross Fixed Capital Formation (Agriculture, Fo...
# 1   Meat indigenous, chicken Gross Production Inde...
# 2                                 Fruit Primary Yield
# 3                                 Tea Import Quantity
# 4           Vegetables, preserved nes Import Quantity
# 5   Gross Fixed Capital Formation (Agriculture, Fo...
# 6   Vegetables and Fruit Primary Gross Production ...
# 7      IPCC Agriculture Emissions Share (CO2eq) (AR5)
# 8   Livestock Gross Production Index Number (2014-...
# 9   Gross Fixed Capital Formation (Agriculture, Fo...
# 10                              Maize Import Quantity
# 11                             Pulses Import Quantity
# 12       Other food Import Value Base Period Quantity
# 13  Milk, skimmed dried Import Value Base Period Q...
# 14         Non-food Import Value Base Period Quantity
# 15     Rice, milled Import Value Base Period Quantity
# 16              Land Use change Emissions Share (CO2)
# 17                       Energy Emissions Share (CH4)
# 18  Value Added (Agriculture, Forestry and Fishing...

# %% [markdown]
# ## Oceania

# %%
political_Oceania= pd.read_csv("drive/Shareddrives/ML_&_Econometrics/Merged/Political_continent/political_Oceania.csv")

# %%
political_Oceania.head(3)
# Out:
#    Year  Area Code Continent  political      67907246  69937225  69705008  \
# 0  2000         10   Oceania       1.33  1.767408e+07       0.0  679.4146
# 1  2000         25   Oceania      -0.74  0.000000e+00       0.0    0.7964
# 2  2000         66   Oceania       0.30  1.364000e+01       0.0    1.7729
#
#       67897246      67897245  67897230  ...  4725610  66555110  4635312  \
# 0  5262833.997  3.092012e+07    6.4932  ...  29405.0  431700.0   2545.0
# 1        0.000  0.000000e+00    0.0000  ...     10.0       7.0    350.0
# 2        5.456  3.273600e+01    0.0000  ...    327.0     175.0    877.0
#
#    18675616    89864    89865  898464  898465  18675622  1719465
# 0    2000.0  33986.0  33524.0    38.0    38.0     520.0     57.0
# 1       NaN    691.0   1369.0    54.0   106.0       NaN     20.0
# 2       NaN   8180.0  10401.0    34.0    41.0       NaN     84.0
#
# [3 rows x 1003 columns]

# %%
# do not drop top NAs because the dataset already small 
print(total_percentage_missing(political_Oceania))

# fill NAs
political_Oceania = political_Oceania.fillna(0)
# Out:
# 0.11825238570004273

# %%
lasso_pipeline(political_Oceania, target_name = 'political')
# Out:
# Training Shape: (224, 999)
# Testing Shape (42, 999)
# score on training dataset 0.7392621272935311
# score on testing dataset 0.6809267530877647
# R squared score on training 0.7392621272935311
# R squared score on testing 0.6809267530877647
# Mean Absolute Error on training 0.39083227787443925
# Mean Absolute Error on testing 0.40246683928712734
#     non_zero_coefficient       code  \
# 0               0.170949   65057264
# 1               0.149905   66107209
# 2               0.021337   69967265
# 3               0.010838    1719465
# 4               0.010295   96072340
# 5               0.007305   96072366
# 6               0.000339  960723611
# 7               0.000278   96072341
# 8               0.000224   96072361
# 9               0.000047   96072360
# 10             -0.092465   66217208
# 11             -0.120663    2041434
# 12             -0.479148   17205312
#
#                                         variable_name
# 0    Food Household Consumption Emissions Share (CO2)
# 1                Agricultural land Share in Land area
# 2           Farm-gate emissions Emissions Share (CH4)
# 3   Roots and Tubers Import Quantity Index (2014-2...
# 4   Cattle, dairy Direct emissions (N2O) (Manure o...
# 5   Cattle, dairy Indirect emissions (N2O) (Manure...
# 6   Cattle, dairy Indirect emissions (N2O that vol...
# 7   Cattle, dairy Direct emissions (N2O) (Manure a...
# 8   Cattle, dairy Indirect emissions (N2O) (Manure...
# 9   Cattle, dairy Indirect emissions (N2O) (Manure...
# 10             Arable land Share in Agricultural land
# 11  Crops Gross per capita Production Index Number...
# 12             Roots and Tubers, Total Area harvested
